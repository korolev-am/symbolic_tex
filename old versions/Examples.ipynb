# %% [markdown]
# ## Немного примеров использования sympy

# %%
import sympy

# %%
sympy.sqrt(5)
# Out:
# sqrt(5)

# %%
sympy.sqrt(28)
# Out:
# 2*sqrt(7)

# %%
from sympy import *
x = Symbol('x')
expr = integrate(x**x, x)
expr
# Out:
# Integral(x**x, x)

# %%
Float('1.33E5')
# Out:
# 133000.000000000

# %%
Rational(3/4)
# Out:
# 3/4

# %%
Rational(3.5)
# Out:
# 7/2

# %%
a = Rational(3, 5)

# %%
a.p, a.q
# Out:
# (3, 5)

# %%
Integer(3.5)
# Out:
# 3

# %%
from sympy import oo
oo
# Out:
# oo

# %%
x = Symbol('x') 
y = Symbol('y') 
expr = x**2 + y**2 
expr
# Out:
# x**2 + y**2

# %%
x = Symbol('x') 
y = Symbol('y')

expr = y*x
expr
# Out:
# x*y

# %%
x = Symbol('x') 
y = Symbol('y') 

expr = x*y
expr
# Out:
# x*y

# %% [markdown]
# проблема - выражение x*y и y*x выводится одинаково. В maxima тоже такая же проблема, пока не нашел решения

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
from sympy.abc import x, z
x
# Out:
# x

# %%
a = Symbol('a')
expr = a**2 + 2*a + 5
expr
# Out:
# a**2 + 2*a + 5

# %%
expr.subs(a, 5)
# Out:
# 40

# %%
expr = "x**2 + 3*x +  2" 
expr1 = sympify(expr)
expr1.subs(x, 2)
# Out:
# 12

# %%
from sympy.abc import r 
expr = pi * r**2 
expr
# Out:
# pi*r**2

# %%
expr.evalf(subs={r: 5})
# Out:
# 78.5398163397448

# %%
from sympy.matrices import Matrix 
m=Matrix([[1, 2, 3], [2, 3, 1]]) 
m
# Out:
# Matrix([
# [1, 2, 3],
# [2, 3, 1]])

# %%
m.shape
# Out:
# (2, 3)

# %%
m.row(0)
# Out:
# Matrix([[1, 2, 3]])

# %%
m.col(1)
# Out:
# Matrix([
# [2],
# [3]])

# %%
m.col_del(1)

# %%
m
# Out:
# Matrix([
# [1, 3],
# [2, 1]])

# %%
m1 = Matrix([[10, 30]]) 
m = m.row_insert(0, m1)
m
# Out:
# Matrix([
# [10, 30],
# [ 1,  3],
# [ 2,  1]])

# %%
M1 = Matrix([[3, 0], [1, 6]]) 
M2 = Matrix([[4, 5], [6, 4]]) 
M = M1 + M2
M
# Out:
# Matrix([
# [7,  5],
# [7, 10]])

# %%
M.det()
# Out:
# 35
